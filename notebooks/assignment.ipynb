# %%
# Assignment


### Question 1

# How do you create a 2x2 subplot grid in matplotlib and select the first subplot?

# Answer:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

# %% [markdown]
# ### Question 2
#
# Question: How to plot a line and set the color to red and style to dash in a matplotlib plot?
#
# Answer:

# %%
plt.plot(x, y, color='red', linestyle='--')

# %% [markdown]
# ### Question 3
#
# Question: How to plot a histogram with 30 bins for `data` in matplotlib?
#
# Answer:

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30)
# Out:
# (array([ 2.,  6.,  3.,  5.,  9., 19., 21., 20., 29., 41., 67., 49., 70.,
#         79., 89., 75., 78., 69., 57., 52., 55., 32., 20., 14., 20., 10.,
#          6.,  1.,  0.,  2.]),
#  array([-2.94487672, -2.7476347 , -2.55039269, -2.35315067, -2.15590865,
#         -1.95866664, -1.76142462, -1.5641826 , -1.36694059, -1.16969857,
#         -0.97245655, -0.77521454, -0.57797252, -0.3807305 , -0.18348849,
#          0.01375353,  0.21099555,  0.40823756,  0.60547958,  0.8027216 ,
#          0.99996361,  1.19720563,  1.39444765,  1.59168966,  1.78893168,
#          1.9861737 ,  2.18341571,  2.38065773,  2.57789975,  2.77514176,
#          2.97238378]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Question 4
#
# Question: How can you set the x-axis and y-axis labels in a matplotlib plot?
#
# Answer:

# %%
plt.xlabel('ValueX')
plt.ylabel('ValueY')
plt.title('Sample Plot')
plt.hist(data, bins=30)
# Out:
# (array([ 2.,  6.,  3.,  5.,  9., 19., 21., 20., 29., 41., 67., 49., 70.,
#         79., 89., 75., 78., 69., 57., 52., 55., 32., 20., 14., 20., 10.,
#          6.,  1.,  0.,  2.]),
#  array([-2.94487672, -2.7476347 , -2.55039269, -2.35315067, -2.15590865,
#         -1.95866664, -1.76142462, -1.5641826 , -1.36694059, -1.16969857,
#         -0.97245655, -0.77521454, -0.57797252, -0.3807305 , -0.18348849,
#          0.01375353,  0.21099555,  0.40823756,  0.60547958,  0.8027216 ,
#          0.99996361,  1.19720563,  1.39444765,  1.59168966,  1.78893168,
#          1.9861737 ,  2.18341571,  2.38065773,  2.57789975,  2.77514176,
#          2.97238378]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Question 5
#
# Question: How do you create a bar plot in seaborn using the `tips` dataset to show the average tip amount per day?

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %% [markdown]
# Answer:

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Question 6
#
# Question: How to create a box plot for total_bill categorized by day in the `tips` dataset using seaborn?
#
# Answer:

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
